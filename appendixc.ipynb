# %%
import pandas as pd
import numpy as np
from scipy import stats
import statsmodels.stats.api as sms
from pathlib import Path
from pandas.plotting import scatter_matrix

# %%
file= Path("/Users/julianawu/Desktop/senic.xlsx")
senic = pd.read_excel(file)

# %% [markdown]
# Dataset C.1: SENIC- Study of Efficacy of Nosocomial Infection Cntrol
#
# Main outcome of this study was infection_risk, the estimated probability of developing hospital-acquired infection
# n=113 randomly selected hospitals

# %%
file1= Path("/Users/julianawu/Desktop/senic.xlsx")
senic = pd.read_excel(file1)
scatter_matrix(senic, figsize=(20, 20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11eced700>,
# ...
#       dtype=object)

# %%
Dataset C.2: County Demographic Information 1990-1992
    
information for the n=440 most populous counties in the U.S.

# %%
file2= Path("/Users/julianawu/Desktop/cdi.xlsx")
cdi= pd.read_excel(file2)
scatter_matrix(cdi, figsize=(30, 30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x124c3d3d0>,
# ...
#       dtype=object)
